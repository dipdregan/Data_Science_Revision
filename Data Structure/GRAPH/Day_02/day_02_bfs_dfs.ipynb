# %% [markdown]
# ## Traversal Techanique
# ### ```1. Breath First Search ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque
def bfs(V,adj,start):
    ## now 1st lets initilize the list which keep track of visited node
    vis = [0]*(V+1)
    ## 2nd thing we need another list which store the traversal 
    bfs_traversal = []
    
    q = deque([start])
    
    ## now let's mark the starting node as visited
    vis[start] = 1

    ### Now let's process the node until queue is empty
    while q:
        node = q.popleft()
        bfs_traversal.append(node)

        ## second thing is that let's find out it's neighbor
        for neighbor in adj[node]:
            if not vis[neighbor]:
                vis[neighbor] = 1
                q.append(neighbor)
    return bfs_traversal

V = 9
adj_list = [[],[2,6],[1,3,4],[2],[2,5],[4,8],[1,7,9],[6,8],[5,7],[6]]
bfs(V,adj_list,1)
# Out:
# [1, 2, 6, 3, 4, 7, 9, 5, 8]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def dfs_travesal(strating_node, adj, vis,travarsal_list):
    vis[strating_node ]  = 1 ## marking strating node as visited node
    travarsal_list.append(strating_node)

    ## Now let's Traverse with all the neighbors
    for neighbor in adj[strating_node]:
        if not vis[neighbor]:
            dfs_travesal(neighbor, adj, vis, travarsal_list)
    return travarsal_list

adj = [[],[2, 3], [1, 5, 6], [1, 4, 7], [3, 8], [2], [2],[3, 8],[4, 7]]
n = len(adj)-1

### Now Let's Initilize the visited List
vis = [0] * (n+1)

travarsal_list = []
dfs_travesal(1,adj,vis,travarsal_list)
# Out:
# [1, 2, 5, 6, 3, 4, 8, 7]

# %% [markdown]
# ### `Question : 1 `
# ```
# There are n cities. Some of them are connected, while some are not. If city a is connected directly with city b, and city b is connected directly with city c, then city a is connected indirectly with city c.
#
# A province is a group of directly or indirectly connected cities and no other cities outside of the group.
#
# You are given an n x n matrix isConnected where isConnected[i][j] = 1 if the ith city and the jth city are directly connected, and isConnected[i][j] = 0 otherwise.
#
# Return the total number of provinces.
#
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque
class Solution(object):

    # def dfs(self, starting_node, adj,vis):
    #     vis[starting_node] = 1
    #     for neighbor in adj[starting_node]:
    #         if not vis[neighbor]:
    #             self.dfs(neighbor, adj, vis)

    def bfs(self, starting_node,adj, vis):
        q = deque([starting_node])
        vis[starting_node] = 1

        while q:
            node = q.popleft()
            for neighbor in adj[node]:
                if not vis[neighbor]:
                    vis[neighbor] = 1
                    q.append(neighbor)



    def findCircleNum(self, isConnected):
        """
        :type isConnected: List[List[int]]
        :rtype: int
        """
        def convert_matrix_to_list(isConnected):
            v = len(isConnected)
            adj_list = [[] for i in range(v)]
            for i in range(v):
                for j in range(v):
                    if isConnected[i][j] == 1 and i!=j:
                        adj_list[i].append(j)
                        adj_list[j].append(i)
            return adj_list
        adj_list = convert_matrix_to_list(isConnected)
        v = len(isConnected)
        vis = [0]*v
        cnt = 0
        for i in range(v):
            if not vis[i]:
                cnt += 1
                # self.dfs(i,adj_list, vis)
                self.bfs(i,adj_list, vis)
        return cnt

sol = Solution()
adj = [[1,1,0],[1,1,0],[0,0,1]]
adj1 = [[1,0,0],[0,1,0],[0,0,1]]
print(sol.findCircleNum(adj))
print(sol.findCircleNum(adj1))
# Out:
# 2
# 3
